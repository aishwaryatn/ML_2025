# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryatn/ML_2025/blob/main/untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def find_s(dataset):
    hypothesis = dataset[0][: -1]
    for example in dataset:
        if example[-1] == "Yes":
            for i in range(len(hypothesis)):
                if example[i] != hypothesis[i]:
                    hypothesis[i] = "?"
    return hypothesis

dataset = [
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Rainy', 'Warm', 'High', 'Strong', 'Warm', 'Change', 'No'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes'],
    ['Rainy', 'Cold', 'High', 'Strong', 'warm', 'Change', 'No']
]

hypothesis = find_s(dataset)
print("Hypothesis:", hypothesis)
# Out:
# Hypothesis: ['Sunny', 'Warm', '?', 'Strong', '?', '?']
